# %% [markdown]
# <a href="https://colab.research.google.com/github/GreenOrange44/AIR/blob/main/HandsOn/FourierTansformFourierTransform.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy import poly1d
p = poly1d([3,2,1])
print(p)
print(p*p)

print(p.deriv())
# Out:
#    2
# 3 x + 2 x + 1
# (poly1d([1.]), poly1d([0.]))
#
# 6 x + 2

# %%
#Fast Fourier Transform

from scipy.fftpack import fft, ifft
import numpy as np

x = np.array([1.0, 1.0, 1.0, 1.0])

y = fft(x)
print(y)

x2 = ifft(y)
print (x2)


print(np.linspace(0, 2, 4))
# Out:
# [4.-0.j 0.+0.j 0.-0.j 0.-0.j]
# [1.+0.j 1.+0.j 1.-0.j 1.+0.j]
# [0.         0.66666667 1.33333333 2.        ]

# %%
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt

t = np.linspace(0, 2, 1000)

frequency = 2
amplitude = 1
signal_wave =amplitude * np.cos(2* np.pi * frequency* t)

plt.plot(t, signal_wave)
plt.xlabel('time')
plt.ylabel('amplitude')
#plt.show()
# Out:
# Text(0, 0.5, 'amplitude')

# %%
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt

t = np.linspace(0, 1, 1000)

frequency1 = 100
frequency2 = 250
amplitude = 1
signal_wave =np.sin(2* np.pi * frequency1* t) + np.sin(2* np.pi * frequency2* t)

plt.plot(t, signal_wave)
plt.xlabel('time')
plt.ylabel('amplitude')
plt.show()

fft = np.fft.fft(signal_wave)
frequencies = np.fft.fftfreq(len(signal_wave), t[1] - t[0])

plt.plot(frequencies, abs(fft))

# %%
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt


# Generate a signal with noise
t = np.linspace(0, 1, 1000)
signal_wave = np.sin(2 * np.pi * 10 * t) + np.random.normal(0, 0.5, len(t))


# Define the window for the moving average filter
window = signal.windows.hann(50)


# Apply the moving average filter
filtered_signal = signal.convolve(signal_wave, window, mode='same') / sum(window)


# Plot the original and filtered signals
plt.plot(t, signal_wave, label='Original Signal')
plt.plot(t, filtered_signal, label='Filtered Signal')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Moving Average Filter')
plt.legend()
plt.show()

# %%
import numpy as np


def calculate_correlation(vector1, vector2):
    if len(vector1) != len(vector2):
        raise ValueError("Vectors must have the same length.")


    n = len(vector1)


    # Calculate the means
    mean1 = np.mean(vector1)
    mean2 = np.mean(vector2)


    # Calculate the standard deviations
    std1 = np.std(vector1)
    std2 = np.std(vector2)


    # Calculate the covariance
    covariance = np.sum((vector1 - mean1) * (vector2 - mean2)) / n


    # Calculate the correlation coefficient
    correlation = covariance / (std1 * std2)


    return correlation


# Example usage
vector1 = [1,2,3,4,5]
vector2 = [8,234,30,14,-75]


correlation = calculate_correlation(vector1, vector2)
print("Correlation coefficient:", correlation)
# Out:
# Correlation coefficient: -0.5320378934055863

# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt
x = [100, 200, 300, 400]
y = [200, 300, 500, 400]

#line plot
plt.plot(x, y)
plt.show()
#scatter plot
plt.scatter(x, y)
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16])
plt.axis([0, 6, 0, 20])
plt.show()

# %%
 # data to display on plots
x = [1,2,3]
y = [1,2,4]
# This will plot a simple line chart
# with elements of x as x axis and y
# as y axis
plt.plot(x, y)
plt.title("Line Chart")
# Adding the legends
plt.legend(["Pressure vs Temp."])
plt.show()

# %%
# data to display on plots
x = [1,2,3,4,5,6,7]
y = [3,2,1,14,5,16,7]
# This will plot a simple bar chart
plt.bar(x, y)
# Title to the plot
plt.title("Bar Chart")
# Adding the legends
plt.legend(["bar"])
plt.show()

# %%
import matplotlib.pyplot as plt


# Your data
x = [1, 2, 3, 1, 2, 3, 1, 2, 1,1,4,4,4,4,4,5,5,6,6,6,6,6,6,6,1,2]


# Specifying bin edges
bin_edges = [0.5, 1.5, 2.5, 3.5,4.5,5.5,6.5]  # These edges create bins: (0.5, 1.5], (1.5, 2.5], (2.5, 3.5]


# Plotting the histogram
plt.hist(x, bins=bin_edges, alpha=0.7, color='blue')
plt.title('Histogram of X with Specified Bin Edges')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
x=[25,65,40,75,25,65,75,75,75,40,25]
bin = [20,30,40,50,60,70,80,90]
plt.hist(x, bins = bin, alpha = 0.7)
# Out:
# (array([3., 0., 2., 0., 2., 4., 0.]),
#  array([20., 30., 40., 50., 60., 70., 80., 90.]),
#  <BarContainer object of 7 artists>)

# %%
import matplotlib.pyplot as plt


# Your data
x = [25, 65, 40, 75, 25, 65, 75, 75, 75, 40, 25]


# Specifying bin edges
bin_edges = [20, 30, 50, 70, 80]  # Adjusted to better fit the data range


# Plotting the histogram
plt.hist(x, bins=bin_edges, alpha=0.7, color='blue')
plt.title('Histogram of X with Specified Bin Edges')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
np.random.seed(0)
x= np.random.randn(100)
y = np.random.randn(100)
colors = np.random.rand(100)


plt.scatter(x, y, c=colors, cmap='viridis')  # 'c' specifies the color of each data point
plt.colorbar()  # Add a colorbar for reference


# Set labels and title
plt.xlabel('X-axis')  # Set the x-axis label
plt.ylabel('Y-axis')  # Set the y-axis label
plt.title('Scatter Plot of Random Data')  # Set the title of the scatter plot


# Show the scatter plot
plt.show()

# %%
np.random.seed(0)

x = [3, 1, 5, 12, 2, 6, 4]
y = [3, 2, 1, 4, 5, 6, 7]
colors = np.random.rand(7)  # Generate random colors for each data point


# Create a scatter plot
plt.scatter(x, y, c=colors, cmap='viridis')  # 'c' specifies the color of each data point
plt.colorbar()  # Add a colorbar for reference


# Set labels and title
plt.xlabel('X-axis')  # Set the x-axis label
plt.ylabel('Y-axis')  # Set the y-axis label
plt.title('Scatter Plot of Random Data')  # Set the title of the scatter plot


# Show the scatter plot
plt.show()

# %%
import matplotlib.pyplot as plt


# Define the data
labels = ['Apples', 'Bananas', 'Oranges', 'Grapes']  # Categories/labels for each slice of the pie chart
sizes = [35, 30, 20, 15]  # Sizes/values for each slice of the pie chart
colors = ['red', 'yellow', 'orange', 'green']  # Colors for each slice of the pie chart


# Create a pie chart
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)


# Set title
plt.title('Pie Chart of Fruit Distribution')


# Show the pie chart
plt.show()

# %%
import matplotlib.pyplot as plt


# Define the data
labels = ['Frogs', 'Snakes']  # Categories/labels for each slice of the pie chart
sizes = [50, 40]  # Sizes/values for each slice of the pie chart
colors = ['red', 'yellow']  # Colors for each slice of the pie chart


# Create a pie chart
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)



# Set title
plt.title('Pie Chart of Fruit Distribution')
# Out:
# Text(0.5, 1.0, 'Pie Chart of Fruit Distribution')

# %%
import matplotlib.pyplot as plt
import numpy as np




n_points = 100
x = np.linspace(-5, 5, n_points)
y = np.linspace(-5, 5, n_points)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 - Y**2)) #note it's capital X(mesh itself) not small x


# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis')


# Set labels and title
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
ax.set_title('3D Plot of Function')


# Show the 3D plot
plt.show()
# Out:
# <ipython-input-22-42452a31faa6>:11: RuntimeWarning: invalid value encountered in sqrt
#   Z = np.sin(np.sqrt(X**2 - Y**2))

# %%
import numpy as np



#my_sin = np.sin(var_on_x)
#print(my_sin)

var_on_x = np.linspace(-np.pi, np.pi, 1000, endpoint=True) # data on x axis


my_cos = np.cos(var_on_x)# data on y axis
my_sin = np.sin(var_on_x)
plt.plot(var_on_x, my_sin)
var_on_y_cos= np.cos(var_on_x)
plt.plot(var_on_x, var_on_y_cos)




plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


# Create a figure of size 15x12 inches, 1500 dots per inch
plt.figure(figsize=(6, 6), dpi=1500)


var_on_x = np.linspace(-np.pi, np.pi, 256, endpoint=True)


my_cos = np.cos(var_on_x)
var_on_y_sin= np.sin(var_on_x)


plt.plot(var_on_x, my_cos)
plt.plot(var_on_x, var_on_y_sin)


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt




plt.figure(figsize=(5, 5), dpi=150)
var_on_x = np.linspace(-np.pi, np.pi, 256, endpoint=True)


my_cos = np.cos(var_on_x)
var_on_y_sin= np.sin(var_on_x)




plt.plot(var_on_x, my_cos, color="magenta", linewidth=1.0, linestyle="--")
plt.plot(var_on_x, var_on_y_sin, color="yellow", linewidth=2.0, linestyle="-.")


# Set x limits
#plt.xlim(-5, 5)
# Set y limits
#plt.ylim(-1.5, 1.5)




plt.show()

# %%
x = np.linspace(1,10,1000)
y = x*x*x

plt.plot(x, y)
plt.show()

# %%
import numpy as np
x_data = np.linspace(0, 10, 11)
y_data = x_data ** 3



# subplot commands
# Syntax: plt.subplot(num_rows, num_cols, plot_seq)
plt.subplot(1,2,1)
plt.plot(x_data, y_data, 'y--') # More on color options later


plt.subplot(1,2,2)
plt.plot(y_data, x_data, 'm*-');

# %%
import numpy as np
x_data = np.linspace(0, 10, 11)
y_data = x_data ** 3



# subplot commands
# Syntax: plt.subplot(num_rows, num_cols, plot_seq)
plt.subplot(2,1,1)
plt.plot(x_data, y_data, 'y--') # More on color options later


plt.subplot(2,1,2)
plt.plot(y_data, x_data, 'm*-');

# %%
import cv2
import matplotlib.pyplot as plt


# Load the image using OpenCV
image = cv2.imread('Ima1.jpg', cv2.IMREAD_GRAYSCALE)  # Replace 'path_to_image' with the actual path to the image file


# Perform histogram equalization using OpenCV
equalized_image = cv2.equalizeHist(image)


# Display the original and equalized images using Matplotlib
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
axes[0].imshow(image, cmap='gray')
axes[0].set_title('Original Image')
axes[1].imshow(equalized_image, cmap='gray')
axes[1].set_title('Equalized Image')
plt.show()

# %%
import pandas as pd
pd.__version__
# Out:
# '2.0.3'

# %%
score={"ABC":91, "PQR":30,"Elon":86,"Tom":65,"Tim":93,"XYZ":11, "def":30,"ghi":56,"jkl":45,"mno":33} #dictionary
marks=pd.Series(score) # Convert to Series
marks
# Out:
# ABC     91
# PQR     30
# Elon    86
# Tom     65
# Tim     93
# XYZ     11
# def     30
# ghi     56
# jkl     45
# mno     33
# dtype: int64

# %%
marks[marks >= 75]
# Out:
# ABC     91
# Elon    86
# Tim     93
# dtype: int64

# %%
marks[marks < 35] = 35
marks
# Out:
# ABC     91
# PQR     35
# Elon    86
# Tom     65
# Tim     93
# XYZ     35
# def     35
# ghi     56
# jkl     45
# mno     35
# dtype: int64

# %%
score={"Jane":91, "Bill":80,"Elon":86,"Tom":65,"Tim":93} #dictionary
names=pd.Series(score) # Convert to Series
names


'Tom' in names

n2=names/10
n2

n3 = names**2
n3

# %%
names.isnull()

# %%
import pandas as pd

df=pd.read_csv("Sale_Stat.csv")

df.head()

df
# Out:
#    Sr.No.  Season  F1  F2 Sale_val
# 0       1  Summer   1  10       No
# 1       2   Rainy   2   3      Yes
# 2       3  Summer   3   2       No
# 3       4   Rainy   1   6      Yes
# 4       5  Summer   2   4       No
# 5       6  Winter   5   8       No

# %%
df.head()

df.tail()
# Out:
#    Sr.No.  Season  F1  F2 Sale_val
# 1       2   Rainy   2   3      Yes
# 2       3  Summer   3   2       No
# 3       4   Rainy   1   6      Yes
# 4       5  Summer   2   4       No
# 5       6  Winter   5   8       No

# %%
df.dtypes

df.describe()#statistical summary

df.Season.describe()

df.Season.value_counts()
# Out:
# Season
# Summer    3
# Rainy     2
# Winter    1
# Name: count, dtype: int64

# %%
df.Season.value_counts(normalize=True)

df.Season.unique()

df.Season.nunique()
# Out:
# 3

# %%
pd.crosstab(df.Season, df.Sale_val)
# Out:
# Sale_val  No  Yes
# Season
# Rainy      0    2
# Summer     3    0
# Winter     1    0

# %%
df.F1.plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.F1.value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='F1'>

# %%
series1 = df['F1']
print(series1)m
# Out:
# 0    1
# 1    2
# 2    3
# 3    1
# 4    2
# 5    5
# Name: F1, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Create a Series
series = pd.Series([1, 3, 5, 2, 4, 6, 8, 7, 9])


# Line plot
series.plot()
plt.show()


# Bar plot
series.plot(kind='bar')
plt.show()

# %%
# Create a Series
import numpy as np
series = pd.Series([1, np.nan, 5, 2, 4, np.nan, 8, 7, 9])


series
# Out:
# 0    1.0
# 1    NaN
# 2    5.0
# 3    2.0
# 4    4.0
# 5    NaN
# 6    8.0
# 7    7.0
# 8    9.0
# dtype: float64

# %%
#to drop NaN

clean_series = series.dropna()

#now not a continous index
#so not a good index

clean_series
# Out:
# 0    1.0
# 2    5.0
# 3    2.0
# 4    4.0
# 6    8.0
# 7    7.0
# 8    9.0
# dtype: float64

# %%
#to reset the index

clean_series = clean_series.reset_index(drop=True)
clean_series
# Out:
# 0    1.0
# 1    5.0
# 2    2.0
# 3    4.0
# 4    8.0
# 5    7.0
# 6    9.0
# dtype: float64

# %%
series2 = pd.Series([np.nan,1, np.nan, 5, 2, 4, np.nan, 8, 7, 9])
filled_series = series2.fillna(0)
print(series2)
print(filled_series)
# Out:
# 0    NaN
# 1    1.0
# 2    NaN
# 3    5.0
# 4    2.0
# 5    4.0
# 6    NaN
# 7    8.0
# 8    7.0
# 9    9.0
# dtype: float64
# 0    0.0
# 1    1.0
# 2    0.0
# 3    5.0
# 4    2.0
# 5    4.0
# 6    0.0
# 7    8.0
# 8    7.0
# 9    9.0
# dtype: float64

# %%
filled_series_ffill = series2.fillna(method='ffill')
filled_series_ffill
# Out:
# 0    NaN
# 1    1.0
# 2    1.0
# 3    5.0
# 4    2.0
# 5    4.0
# 6    4.0
# 7    8.0
# 8    7.0
# 9    9.0
# dtype: float64

# %%
import pandas as pd
import numpy as np


series = pd.Series([1, np.nan, 5, 2, 4, np.nan, 8, 7, 9])
mean_value = series.mean()
filled_series = series.fillna(mean_value)


print(filled_series)
# Out:
# 0    1.000000
# 1    5.142857
# 2    5.000000
# 3    2.000000
# 4    4.000000
# 5    5.142857
# 6    8.000000
# 7    7.000000
# 8    9.000000
# dtype: float64

# %%
my_columns=["Season","Sale_val"]
df[my_columns]

df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
#if i want a particular row from a data frame
#loc always take the labels, if labels are string enter that particular string
df.loc[0]

df.loc[3]
# Out:
# Sr.No.          4
# Season      Rainy
# F1              1
# F2              6
# Sale_val      Yes
# Name: 3, dtype: object

# %%
#here in loc m:n slicing we go to n itself

df.loc[0:2]
# Out:
#    Sr.No.  Season  F1  F2 Sale_val
# 0       1  Summer   1  10       No
# 1       2   Rainy   2   3      Yes
# 2       3  Summer   3   2       No

# %%
#creating new column
df["F2_greater"]=df.F2>=5
df
# Out:
#    Sr.No.  Season  F1  F2 Sale_val  F2_greater
# 0       1  Summer   1  10       No        True
# 1       2   Rainy   2   3      Yes       False
# 2       3  Summer   3   2       No       False
# 3       4   Rainy   1   6      Yes        True
# 4       5  Summer   2   4       No       False
# 5       6  Winter   5   8       No        True

# %%
del df["F2_greater"]
df
# Out:
#    Sr.No.  Season  F1  F2 Sale_val
# 0       1  Summer   1  10       No
# 1       2   Rainy   2   3      Yes
# 2       3  Summer   3   2       No
# 3       4   Rainy   1   6      Yes
# 4       5  Summer   2   4       No
# 5       6  Winter   5   8       No

# %%
#to find the transpose of the df
new_df = df.T
new_df
# Out:
#                0      1       2      3       4       5
# Sr.No.         1      2       3      4       5       6
# Season    Summer  Rainy  Summer  Rainy  Summer  Winter
# F1             1      2       3      1       2       5
# F2            10      3       2      6       4       8
# Sale_val      No    Yes      No    Yes      No      No

# %%
#to create a data from dict
